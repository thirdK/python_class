# %%
# 파이썬 API 를 이용한 가상화폐 시스템
# !pip install pybithumb    설치
import pybithumb

# %%
price = pybithumb.get_current_price("BTC");
print(price)
price = pybithumb.get_current_price("ETH");
print(price)
# Out:
# 56346000.0
# 3973000.0

# %%
tickers = pybithumb.get_tickers()
print(len(tickers))
print(tickers)
# Out:
# 196
# ['BTC', 'ETH', 'LTC', 'ETC', 'XRP', 'BCH', 'QTUM', 'BTG', 'EOS', 'ICX', 'TRX', 'ELF', 'OMG', 'KNC', 'GLM', 'ZIL', 'WAXP', 'POWR', 'LRC', 'STEEM', 'STRAX', 'ZRX', 'REP', 'XEM', 'SNT', 'ADA', 'CTXC', 'BAT', 'WTC', 'THETA', 'LOOM', 'WAVES', 'LINK', 'ENJ', 'VET', 'MTL', 'IOST', 'TMTG', 'QKC', 'ATOLO', 'AMO', 'BSV', 'ORBS', 'TFUEL', 'VALOR', 'CON', 'ANKR', 'MIX', 'CRO', 'FX', 'CHR', 'MBL', 'MXC', 'FCT2', 'TRV', 'DAD', 'WOM', 'SOC', 'BOA', 'MEV', 'SXP', 'COS', 'APIX', 'EL', 'BASIC', 'HIVE', 'XPR', 'VRA', 'FIT', 'EGG', 'BORA', 'ARPA', 'CTC', 'APM', 'CKB', 'AERGO', 'ANW', 'CENNZ', 'EVZ', 'CYCLUB', 'SRM', 'QTCON', 'UNI', 'YFI', 'UMA', 'AAVE', 'COMP', 'REN', 'BAL', 'RSR', 'NMR', 'RLC', 'UOS', 'SAND', 'GOM2', 'RINGX', 'BEL', 'OBSR', 'ORC', 'POLA', 'AWO', 'ADP', 'DVI', 'GHX', 'MIR', 'MVC', 'BLY', 'WOZX', 'ANV', 'GRT', 'MM', 'BIOT', 'XNO', 'SNX', 'SOFI', 'COLA', 'OXT', 'LINA', 'MAP', 'AQT', 'WIKEN', 'CTSI', 'MANA', 'LPT', 'MKR', 'SUSHI', 'ASM', 'PUNDIX', 'CELR', 'CWD', 'ARW', 'FRONT', 'RLY', 'OCEAN', 'BFC', 'ALICE', 'COTI', 'CAKE', 'BNT', 'XVS', 'CHZ', 'AXS', 'DAO', 'DAI', 'MATIC', 'WOO', 'BAKE', 'VELO', 'BCD', 'XLM', 'VSYS', 'IPX', 'WICC', 'ONT', 'LUNA', 'AION', 'META', 'KLAY', 'ONG', 'ALGO', 'JST', 'XTZ', 'MLK', 'WEMIX', 'DOT', 'ATOM', 'SSX', 'TEMCO', 'HIBS', 'BURGER', 'DOGE', 'KSM', 'CTK', 'XYM', 'BNB', 'NFT', 'SUN', 'XEC', 'PCI', 'SOL', 'EGLD', 'GO', 'DFA', 'C98', 'MED', '1INCH', 'BOBA', 'GALA', 'BTT', 'EFI', 'CSPR', 'AVAX', 'TDROP', 'SPRT', 'NPT', 'T']

# %%
tickers = pybithumb.get_tickers()
for i in tickers:
    # print(i, "-", pybithumb.get_current_price(i))
    print(f"{i} - {pybithumb.get_current_price(i)}")
print("임태종")
# Out:
# BTC - 56598000.0
# ETH - 3998000.0
# LTC - 156400.0
# ETC - 58500.0
# XRP - 1043.0
# BCH - 451300.0
# QTUM - 10210.0
# BTG - 52700.0
# EOS - 3279.0
# ICX - 1179.0
# TRX - 83.14
# ELF - 476.3
# OMG - 6595.0
# KNC - 3815.0
# GLM - 663.8
# ZIL - 126.5
# WAXP - 437.1
# POWR - 701.4
# LRC - 1336.0
# STEEM - 486.0
# STRAX - 1485.0
# ZRX - 885.2
# REP - 19560.0
# XEM - 139.9
# SNT - 93.28
# ADA - 1424.0
# CTXC - 325.4
# BAT - 1094.0
# WTC - 642.7
# THETA - 4354.0
# LOOM - 120.0
# WAVES - 38330.0
# LINK - 20260.0
# ENJ - 2152.0
# VET - 92.21
# MTL - 2465.0
# IOST - 42.35
# TMTG - 3.682
# QKC - 26.5
# ATOLO - 48.15
# AMO - 2.23
# BSV - 114700.0
# ORBS - 106.0
# TFUEL - 236.9
# VALOR - 676.1
# CON - 41.35
# ANKR - 105.9
# MIX - 14.46
# CRO - 586.4
# FX - 740.7
# CHR - 606.4
# MBL - 15.45
# MXC - 123.8
# FCT2 - 144.9
# TRV - 22.03
# DAD - 178.5
# WOM - 137.9
# SOC - 16.06
# BOA - 141.8
# MEV - 28.05
# SXP - 2116.0
# COS - 21.26
# APIX - 67.23
# EL - 9.194
# BASIC - 6.06
# HIVE - 1385.0
# XPR - 14.72
# VRA - 33.61
# FIT - 2.755
# EGG - 50.71
# BORA - 1132.0
# ARPA - 101.8
# CTC - 1640.0
# APM - 36.1
# CKB - 15.52
# AERGO - 328.6
# ANW - 37.8
# CENNZ - 143.2
# EVZ - 78.9
# CYCLUB - 20.51
# SRM - 3688.0
# QTCON - 8.313
# UNI - 13710.0
# YFI - 28394000.0
# UMA - 9605.0
# AAVE - 204900.0
# COMP - 154300.0
# REN - 511.8
# BAL - 16890.0
# RSR - 20.56
# NMR - 37410.0
# RLC - 2767.0
# UOS - 1430.0
# SAND - 4285.0
# GOM2 - 38.88
# RINGX - 42.96
# BEL - 1291.0
# OBSR - 4.969
# ORC - 527.0
# POLA - 122.5
# AWO - 40.19
# ADP - 50.7
# DVI - 490.0
# GHX - 70.0
# MIR - 2011.0
# MVC - 21.19
# BLY - 26.29
# WOZX - 207.5
# ANV - 576.0
# GRT - 539.1
# MM - 714.1
# BIOT - 43.06
# XNO - 78.94
# SNX - 6535.0
# SOFI - 213.7
# COLA - 198.4
# OXT - 335.3
# LINA - 31.72
# MAP - 30.53
# AQT - 3775.0
# WIKEN - 29.52
# CTSI - 514.6
# MANA - 3277.0
# LPT - 35000.0
# MKR - 2498000.0
# SUSHI - 4826.0
# ASM - 70.2
# PUNDIX - 1122.0
# CELR - 69.4
# CWD - 130.2
# ARW - 1382.0
# FRONT - 683.0
# RLY - 262.4
# OCEAN - 748.2
# BFC - 204.7
# ALICE - 9215.0
# COTI - 315.3
# CAKE - 9690.0
# BNT - 3286.0
# XVS - 13140.0
# CHZ - 322.3
# AXS - 81000.0
# DAO - 3197.0
# DAI - 1198.0
# MATIC - 2039.0
# WOO - 739.0
# BAKE - 821.2
# VELO - 88.49
# BCD - 643.8
# XLM - 280.1
# VSYS - 16.81
# IPX - 61.51
# WICC - 170.1
# ONT - 772.2
# LUNA - 115100.0
# AION - 124.8
# META - 106.0
# KLAY - 1440.0
# ONG - 1002.0
# ALGO - 1145.0
# JST - 74.11
# XTZ - 4727.0
# MLK - 1111.0
# WEMIX - 5850.0
# DOT - 27430.0
# ATOM - 36410.0
# SSX - 64.48
# TEMCO - 6.909
# HIBS - 3.214
# BURGER - 1974.0
# DOGE - 179.4
# KSM - 208600.0
# CTK - 1733.0
# XYM - 183.0
# BNB - 519500.0
# NFT - 0.0022
# SUN - 17.91
# XEC - 0.1186
# PCI - 975.0
# SOL - 128500.0
# EGLD - 237000.0
# GO - 30.78
# DFA - 1439.0
# C98 - 2056.0
# MED - 56.51
# 1INCH - 2144.0
# BOBA - 1604.0
# GALA - 323.5
# BTT - 0.0026
# EFI - 524.6
# CSPR - 92.27
# AVAX - 110000.0
# TDROP - 35.4
# SPRT - 2472.0
# NPT - 10160.0
# T - 159.0
# 임태종
